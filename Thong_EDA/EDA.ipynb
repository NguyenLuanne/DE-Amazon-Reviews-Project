# %% [markdown]
# # EDA the compiled data

# %%
import numpy as np
import pandas as pd

# %%
reviews_data = pd.read_parquet('../data/reviews_data.parquet')
reviews_data.head()
# Out:
#    rating               title  \
# 0     5.0          Great gift
# 1     5.0    amazon gift card
# 2     5.0        perfect gift
# 3     5.0        Nice looking
# 4     1.0  Not $10 Gift Cards
#
#                                                 text images        asin  \
# 0                Having Amazon money is always good.     []  B00IX1I3G6
# 1  Always the perfect gift.  I have never given o...     []  B005ESMMWW
# 2  When you have a person who is hard to shop for...     []  B01K8RIM5Y
# 3  The tin is a nice touch and pretty large.  It'...     []  B0091JKVU0
# 4  I bought this pack of Starbucks Gift cards in ...     []  B00FTGTM5E
#
#   parent_asin                       user_id               timestamp  \
# 0  B00IX1I3G6  AHZ6XMOLEWA67S3TX7IWEXXGWSOA 2019-02-11 06:22:38.332
# 1  B005ESMMWW  AFZUK3MTBIBEDQOPAK3OATUOUKLA 2020-09-12 01:45:58.120
# 2  B005S28ZES  AFZUK3MTBIBEDQOPAK3OATUOUKLA 2018-09-03 01:58:49.239
# 3  B00ADR2LV6  AFZUK3MTBIBEDQOPAK3OATUOUKLA 2014-12-13 02:59:37.000
# ...

# %%
meta_data = pd.read_parquet('../data/meta_data.parquet')
meta_data.head()
# Out:
#   main_category                                              title  \
# 0    Gift Cards  Amazon.com Gift Card in Gift Tag (Various Desi...
# 1    Gift Cards  $25 Mastercard Gift Card (plus $3.95 Purchase ...
# 2    Gift Cards                   Tractor Supply Company Gift Card
# 3    Gift Cards                                  Staples Gift Card
# 4    Gift Cards                  Ninety Nine Restaurants Gift Card
#
#    average_rating  rating_number  \
# 0             4.8           1006
# 1             2.5             11
# 2             4.9           2708
# 3             4.8            351
# 4             4.8            443
#
#                                             features  \
# 0  [Gift Card is affixed inside a gift tag, Gift ...
# 1  [This card is non-reloadable. No expiration of...
# 2  [Tractor Supply Company is the largest operato...
# 3  [Staples Gift Cards - Giving the perfect gift ...
# 4  [Ninety Nine Restaurants are a comfortable pla...
#
# ...

# %%
reviews_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 864678 entries, 0 to 864677
# Data columns (total 10 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   rating             864678 non-null  float64
#  1   title              864678 non-null  object
#  2   text               864678 non-null  object
#  3   images             864678 non-null  object
#  4   asin               864678 non-null  object
#  5   parent_asin        864678 non-null  object
#  6   user_id            864678 non-null  object
#  7   timestamp          864678 non-null  datetime64[ns]
#  8   helpful_vote       864678 non-null  int64
#  9   verified_purchase  864678 non-null  bool
# dtypes: bool(1), datetime64[ns](1), float64(1), int64(1), object(6)
# memory usage: 60.2+ MB

# %%
meta_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135999 entries, 0 to 135998
# Data columns (total 16 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   main_category    135829 non-null  object
#  1   title            135999 non-null  object
#  2   average_rating   135999 non-null  float64
#  3   rating_number    135999 non-null  int64
#  4   features         135999 non-null  object
#  5   description      135999 non-null  object
#  6   price            51041 non-null   float64
#  7   images           135999 non-null  object
#  8   videos           135999 non-null  object
#  9   store            129220 non-null  object
#  10  categories       135999 non-null  object
#  11  details          135999 non-null  object
#  12  parent_asin      135999 non-null  object
#  13  bought_together  0 non-null       object
#  14  subtitle         1 non-null       object
#  15  author           0 non-null       float64
# ...

# %%
null_categories = meta_data[meta_data['main_category'].isna()]
null_categories
# Out:
#      main_category                                              title  \
# 39            None  QuickGifts Cattle Baron Restaurant Gift Card (...
# 41            None                     Justice/ Limited Too Gift Card
# 50            None                          Birdman Academy Gift Card
# 52            None                   QuickGifts Alexander's Gift Card
# 57            None                               Maggiano's Gift Card
# ...            ...                                                ...
# 1129          None                                   iTunes Gift Card
# 1130          None                             Claim Jumper Gift Card
# 1131          None                             Claim Jumper Gift Card
# 1132          None                            Smoothie King Gift Card
# 1135          None                       Outback Steakhouse Gift Card
#
#       average_rating  rating_number  \
# 39               4.8              4
# 41               4.1             11
# ...

# %%
# Check if gift cards is the main category
null_categories['categories'].apply(lambda x: True if 'Gift Cards' in x else False).value_counts()
# Out:
# categories
# True    170
# Name: count, dtype: int64

# %%
meta_data['main_category'] = meta_data['main_category'].fillna('Gift Cards')
meta_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135999 entries, 0 to 135998
# Data columns (total 16 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   main_category    135999 non-null  object
#  1   title            135999 non-null  object
#  2   average_rating   135999 non-null  float64
#  3   rating_number    135999 non-null  int64
#  4   features         135999 non-null  object
#  5   description      135999 non-null  object
#  6   price            51041 non-null   float64
#  7   images           135999 non-null  object
#  8   videos           135999 non-null  object
#  9   store            129220 non-null  object
#  10  categories       135999 non-null  object
#  11  details          135999 non-null  object
#  12  parent_asin      135999 non-null  object
#  13  bought_together  0 non-null       object
#  14  subtitle         1 non-null       object
#  15  author           0 non-null       float64
# ...

# %%
main_category_values = meta_data['main_category'].value_counts()
main_category_outliers = main_category_values[main_category_values < 10].index.tolist()

# %%
meta_data[meta_data['main_category'].isin(main_category_outliers)]
# Out:
#                 main_category  \
# 13            Office Products
# 100               Amazon Home
# 159               Amazon Home
# 216                  Software
# 225              Toys & Games
# 237               Video Games
# 354               Amazon Home
# 370                  Software
# 382         Sports & Outdoors
# 387                   Grocery
# 410                All Beauty
# 444                   Grocery
# 495               Amazon Home
# 499           Office Products
# 502           Office Products
# 578               Amazon Home
# 598            AMAZON FASHION
# 708               Amazon Home
# 758               Video Games
# 763           All Electronics
# 818     Arts, Crafts & Sewing
# 824           Office Products
# 857               Amazon Home
# 874           Office Products
# 911               Video Games
# 944               Amazon Home
# 1000          Office Products
# 1044          Office Products
# 1081                    Books
# 1088        Sports & Outdoors
# ...

# %%
main_category_outliers
# Out:
# ['Amazon Home',
#  'Office Products',
#  'Video Games',
#  'Software',
#  'Sports & Outdoors',
#  'Grocery',
#  'Books',
#  'Toys & Games',
#  'Arts, Crafts & Sewing',
#  'All Electronics',
#  'AMAZON FASHION',
#  'All Beauty']

# %%
meta_data.describe()
# Out:
#        average_rating  rating_number         price  author
# count   135999.000000  135999.000000  51041.000000     0.0
# mean         4.284203     134.205884     41.022469     NaN
# std          0.820066    1621.432755     95.652489     NaN
# min          1.000000       1.000000      0.010000     NaN
# 25%          4.000000       2.000000     12.950000     NaN
# 50%          4.500000       6.000000     22.990000     NaN
# 75%          5.000000      26.000000     41.000000     NaN
# max          5.000000  185606.000000   4449.000000     NaN
